# %%
# %pip install gqlalchemy python-dotenv yfinance
# Out:
# Collecting gqlalchemy
#   Downloading gqlalchemy-1.8.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dotenv in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: yfinance in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (1.2.0)
# Collecting adlfs<2025.0.0,>=2023.9.0 (from gqlalchemy)
#   Downloading adlfs-2024.12.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting dacite<2.0.0,>=1.6.0 (from gqlalchemy)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting neo4j<6.0.0,>=4.4.3 (from gqlalchemy)
#   Downloading neo4j-5.28.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: networkx<4.0.0,>=2.5.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from gqlalchemy) (3.6.1)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from gqlalchemy) (2.4.2)
# Collecting pandas<=2.2.3 (from gqlalchemy)
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting psutil<7.0,>=5.9 (from gqlalchemy)
#   Downloading psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from gqlalchemy) (2.12.5)
# Collecting pymgclient<2.0.0,>=1.3.1 (from gqlalchemy)
#   Downloading pymgclient-1.5.2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: requests>=2.31 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pytz>=2022.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (4.0.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from yfinance) (16.0)
# Collecting azure-core<2.0.0,>=1.28.0 (from adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Downloading azure_core-1.38.2-py3-none-any.whl.metadata (48 kB)
# Collecting azure-datalake-store<0.1,>=0.0.53 (from adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Downloading azure_datalake_store-0.0.53-py2.py3-none-any.whl.metadata (19 kB)
# Collecting azure-identity (from adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Downloading azure_identity-1.25.2-py3-none-any.whl.metadata (90 kB)
# Collecting azure-storage-blob>=12.17.0 (from adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Downloading azure_storage_blob-12.28.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: fsspec>=2023.12.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (2026.2.0)
# Requirement already satisfied: aiohttp>=3.7.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (3.13.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pandas<=2.2.3->gqlalchemy) (2.9.0.post0)
# Collecting tzdata>=2022.7 (from pandas<=2.2.3->gqlalchemy)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->gqlalchemy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->gqlalchemy) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.3.0->gqlalchemy) (0.4.2)
# Collecting pyopenssl (from pymgclient<2.0.0,>=1.3.1->gqlalchemy)
#   Downloading pyopenssl-25.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (1.22.0)
# Collecting msal<2,>=1.16.0 (from azure-datalake-store<0.1,>=0.0.53->adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Downloading msal-1.35.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: cryptography>=2.1.4 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from azure-storage-blob>=12.17.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy) (46.0.5)
# Collecting isodate>=0.6.1 (from azure-storage-blob>=12.17.0->adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pycparser in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /home/whau/researchProject/venv/genai/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<=2.2.3->gqlalchemy) (1.17.0)
# Collecting msal-extensions>=1.2.0 (from azure-identity->adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs<2025.0.0,>=2023.9.0->gqlalchemy)
#   Using cached pyjwt-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading gqlalchemy-1.8.0-py3-none-any.whl (95 kB)
# Downloading adlfs-2024.12.0-py3-none-any.whl (41 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading neo4j-5.28.3-py3-none-any.whl (313 kB)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 25.1 MB/s eta 0:00:00a 0:00:01
# Downloading psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
# Downloading pymgclient-1.5.2-cp312-cp312-manylinux_2_34_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 29.8 MB/s eta 0:00:00
# Downloading azure_core-1.38.2-py3-none-any.whl (217 kB)
# Downloading azure_datalake_store-0.0.53-py2.py3-none-any.whl (55 kB)
# Downloading azure_storage_blob-12.28.0-py3-none-any.whl (431 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading azure_identity-1.25.2-py3-none-any.whl (191 kB)
# Downloading pyopenssl-25.3.0-py3-none-any.whl (57 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.35.0-py3-none-any.whl (120 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached pyjwt-2.11.0-py3-none-any.whl (28 kB)
# Installing collected packages: tzdata, PyJWT, psutil, neo4j, isodate, dacite, pandas, azure-core, pyopenssl, azure-storage-blob, pymgclient, msal, msal-extensions, azure-datalake-store, azure-identity, adlfs, gqlalchemy
#   Attempting uninstall: psutil
#     Found existing installation: psutil 7.2.2
#     Uninstalling psutil-7.2.2:
#       Successfully uninstalled psutil-7.2.2
#   Attempting uninstall: neo4j
#     Found existing installation: neo4j 6.1.0
#     Uninstalling neo4j-6.1.0:
#       Successfully uninstalled neo4j-6.1.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 3.0.1
#     Uninstalling pandas-3.0.1:
#       Successfully uninstalled pandas-3.0.1
# Successfully installed PyJWT-2.11.0 adlfs-2024.12.0 azure-core-1.38.2 azure-datalake-store-0.0.53 azure-identity-1.25.2 azure-storage-blob-12.28.0 dacite-1.9.2 gqlalchemy-1.8.0 isodate-0.7.2 msal-1.35.0 msal-extensions-1.3.1 neo4j-5.28.3 pandas-2.2.3 psutil-6.1.1 pymgclient-1.5.2 pyopenssl-25.3.0 tzdata-2025.3
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import yfinance as yf
from gqlalchemy import Memgraph
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# ───────────────────────────────────────────────
# 1. Connection Config
# ───────────────────────────────────────────────
HOST = "localhost"
PORT = 7687
USERNAME = os.getenv("MEMGRAPH_USERNAME", "memgraph")  # default is usually no auth
PASSWORD = os.getenv("MEMGRAPH_PASSWORD")              # can be None if no auth is set

# Connect to Memgraph
memgraph = Memgraph(
    host=HOST,
    port=PORT,
    #username=None,          # or "" if you prefer — None is fine
    #password=None,          # explicitly None or omit if no auth
    encrypted=False         # ← this is the key line for local setups
)

def ingest_financial_data(tickers):
    for symbol in tickers:
        # Fetch real data from Yahoo Finance
        stock = yf.Ticker(symbol)
        info = stock.info
        
        # Extract basic entities
        name = info.get('longName', symbol)
        sector = info.get('sector', 'Unknown')
        summary = info.get('longBusinessSummary', 'No summary available.')

        # Create Nodes and Relationships using Cypher
        query = """
        MERGE (c:Company {ticker: $ticker})
        SET c.name = $name, c.summary = $summary
        MERGE (s:Sector {name: $sector})
        MERGE (c)-[:IN_SECTOR]->(s)
        """
        
        memgraph.execute(
            query,
            {
                "ticker": symbol,
                "name": name,
                "sector": sector,
                "summary": summary
            }
        )
        
        print(f"Ingested: {name} in {sector} sector.")


def graph_rag_traversal(target_sector):
    """
    Example of 'Graph Retrieval Fusion':
    Find all companies in a sector and retrieve their summaries for RAG context.
    """
    query = """
    MATCH (s:Sector {name: $sector})<-[:IN_SECTOR]-(c:Company)
    RETURN c.name AS company, c.summary AS context
    """
    
    # Execute and get results
    results = memgraph.execute_and_fetch(query, {"sector": target_sector})
    
    # results is an iterator of dicts → convert to list of formatted strings
    return [
        f"Data for {r['company']}: {r['context'][:200]}..."
        for r in results
    ]
# Out:
# Connection failed: Function 'mg.version' doesn't exist.
# Ingested: Apple Inc. in Technology sector.
# Ingested: Microsoft Corporation in Technology sector.
# Ingested: Alphabet Inc. in Communication Services sector.
# Ingested: Tesla, Inc. in Consumer Cyclical sector.
#
# Retrieved context:
# Data for Apple Inc.: Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal ...
# Data for Microsoft Corporation: Microsoft Corporation develops and supports software, services, devices, and solutions worldwide. The Productivity and Business Processes segment offers Microsoft 365 commercial, enterprise mobility +...

# %%
# ───────────────────────────────────────────────
# Example usage
# ───────────────────────────────────────────────

# Optional: test connection
try:
    version = list(memgraph.execute_and_fetch("RETURN mg.version() AS ver"))[0]["ver"]
    print(f"Connected to Memgraph version: {version}")
except Exception as e:
    print(f"Connection failed: {e}")
    exit(1)

tickers = ["AAPL", "MSFT", "GOOGL", "TSLA"]
ingest_financial_data(tickers)

# Test retrieval
sector = "Technology"  # ← make sure case matches exactly what was ingested
contexts = graph_rag_traversal(sector)

print("\nRetrieved context:")
if not contexts:
    print("No companies found in sector:", sector)
else:
    for line in contexts:
        print(line)
# Out:
# Connection failed: Function 'mg.version' doesn't exist.
# Ingested: Apple Inc. in Technology sector.
# Ingested: Microsoft Corporation in Technology sector.
# Ingested: Alphabet Inc. in Communication Services sector.
# Ingested: Tesla, Inc. in Consumer Cyclical sector.
#
# Retrieved context:
# Data for Apple Inc.: Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal ...
# Data for Microsoft Corporation: Microsoft Corporation develops and supports software, services, devices, and solutions worldwide. The Productivity and Business Processes segment offers Microsoft 365 commercial, enterprise mobility +...
